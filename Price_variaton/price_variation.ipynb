# %%
from binance.client import Client
import requests
import re

# %%
# Define tu API Key y API Secret
api_key = 'TU_API_KEY'
api_secret = 'TU_API_SECRET'

def binance_price():
    # Inicializa el cliente de Binance
    client = Client(api_key, api_secret)
    
    # Obtiene las cotizaciones actuales de todas las criptomonedas
    prices = client.get_all_tickers()
    
    # Almacena los resultados en una lista
    results = []
    for price in prices:
        results.append(f"Symbol: {price['symbol']}, Price: {price['price']}")
    
    return results

# %%
import requests
import re

# Define la URL base de la API de OKX
base_url = 'https://www.okx.com/api/v5/market/tickers'

def okx_price():
    # Define el parámetro del tipo de mercado (SPOT en este caso)
    params = {
        'instType': 'SPOT'
    }
    
    # Realiza la solicitud GET a la API de OKX
    response = requests.get(base_url, params=params)
    
    # Verifica si la solicitud fue exitosa
    if response.status_code == 200:
        data = response.json()
        tickers = data['data']
        # Lista para almacenar los símbolos procesados
        symbols = []
        # Imprime las cotizaciones originales y extrae los símbolos
        for ticker in tickers:
            symbol = ticker['instId']
            price = ticker['last']
            symbols.append(f"Symbol: {symbol}, Price: {price}")           
    else:
        print(f"Error: Unable to fetch data (Status code: {response.status_code})")
        return []

    # Función para eliminar subcadenas entre '-' y ','
    def remove_substrings(lst):
        # Define una expresión regular para encontrar el patrón entre '-' y ','
        pattern = re.compile(r'-')
        
        # Procesa cada elemento de la lista
        new_lst = []
        new_lst = [pattern.sub('', item) for item in lst]
        
        return new_lst

    # Aplica la función a la lista de símbolos
    cleaned_symbols = remove_substrings(symbols)
    
    # Imprime los símbolos procesados
    cleaned_symnols_final = []
    for symbol in cleaned_symbols:
        cleaned_symnols_final.append(symbol)
    
    return cleaned_symnols_final

# %%
print(binance_price())
# Out:
# ['Symbol: ETHBTC, Price: 0.05525000', 'Symbol: LTCBTC, Price: 0.00119300', 'Symbol: BNBBTC, Price: 0.00923600', 'Symbol: NEOBTC, Price: 0.00018460', 'Symbol: QTUMETH, Price: 0.00075600', 'Symbol: EOSETH, Price: 0.00016650', 'Symbol: SNTETH, Price: 0.00000764', 'Symbol: BNTETH, Price: 0.00018300', 'Symbol: BCCBTC, Price: 0.07908100', 'Symbol: GASBTC, Price: 0.00005930', 'Symbol: BNBETH, Price: 0.16710000', 'Symbol: BTCUSDT, Price: 63318.68000000', 'Symbol: ETHUSDT, Price: 3498.11000000', 'Symbol: HSRBTC, Price: 0.00041400', 'Symbol: OAXETH, Price: 0.00017780', 'Symbol: DNTETH, Price: 0.00002801', 'Symbol: MCOETH, Price: 0.00577200', 'Symbol: ICNETH, Price: 0.00166300', 'Symbol: MCOBTC, Price: 0.00021140', 'Symbol: WTCBTC, Price: 0.00000024', 'Symbol: WTCETH, Price: 0.00023700', 'Symbol: LRCBTC, Price: 0.00000291', 'Symbol: LRCETH, Price: 0.00005285', 'Symbol: QTUMBTC, Price: 0.00004161', 'Symbol: YOYOBTC, Price: 0.00000008', 'Symbol: OMGBTC, Price: 0.00003080', 'Symbol: OMGETH, Price: 0.00079100', 'Symbol: ZRXBTC, Price: 0.00000588', 'Symbol: ZRXETH, Price: 0.00009940', 'Symbol: STRATBTC, Price: 0.00003085', 'Symbol: STRATETH, Price: 0.00105300', 'Symbol: SNGLSBTC, Price: 0.00000013', 'Symbol: SNGLSETH, Price: 0.00005306', 'Symbol: BQXBTC, Price: 0.00008703', 'Symbol: BQXETH, Price: 0.00126350', 'Symbol: KNCBTC, Price: 0.00000872', 'Symbol: KNCETH, Price: 0.00039410', 'Symbol: FUNBTC, Price: 0.00000029', 'Symbol: FUNETH, Price: 0.00000146', 'Symbol: SNMBTC, Price: 0.00000057', 'Symbol: SNMETH, Price: 0.00004986', 'Symbol: NEOETH, Price: 0.00477500', 'Symbol: IOTABTC, Price: 0.00000271', 'Symbol: IOTAETH, Price: 0.00004930', 'Symbol: LINKBTC, Price: 0.00022650', 'Symbol: LINKETH, Price: 0.00409800', 'Symbol: XVGBTC, Price: 0.00000015', 'Symbol: XVGETH, Price: 0.00000124', 'Symbol: SALTBTC, Price: 0.00004250', 'Symbol: SALTETH, Price: 0.00113800', 'Symbol: MDABTC, Price: 0.00000382', 'Symbol: MDAETH, Price: 0.00181150', 'Symbol: MTLBTC, Price: 0.00001794', 'Symbol: MTLETH, Price: 0.00068340', 'Symbol: SUBBTC, Price: 0.00000457', 'Symbol: SUBETH, Price: 0.00012334', 'Symbol: EOSBTC, Price: 0.00000923', 'Symbol: SNTBTC, Price: 0.00000042', 'Symbol: ETCETH, Price: 0.00682000', 'Symbol: ETCBTC, Price: 0.00037700', 'Symbol: MTHBTC, Price: 0.00000023', 'Symbol: MTHETH, Price: 0.00004135', 'Symbol: ENGBTC, Price: 0.00006200', 'Symbol: ENGETH, Price: 0.00186480', 'Symbol: DNTBTC, Price: 0.00000186', 'Symbol: ZECBTC, Price: 0.00032750', 'Symbol: ZECETH, Price: 0.00597000', 'Symbol: BNTBTC, Price: 0.00001015', 'Symbol: ASTBTC, Price: 0.00000170', 'Symbol: ASTETH, Price: 0.00006960', 'Symbol: DASHBTC, Price: 0.00039150', 'Symbol: DASHETH, Price: 0.00714000', 'Symbol: OAXBTC, Price: 0.00000281', 'Symbol: ICNBTC, Price: 0.00005742', 'Symbol: BTGBTC, Price: 0.00091300', 'Symbol: BTGETH, Price: 0.05274500', 'Symbol: EVXBTC, Price: 0.00000274', 'Symbol: EVXETH, Price: 0.00062490', 'Symbol: REQBTC, Price: 0.00000175', 'Symbol: REQETH, Price: 0.00004995', 'Symbol: VIBBTC, Price: 0.00000126', 'Symbol: VIBETH, Price: 0.00003450', 'Symbol: HSRETH, Price: 0.01247400', 'Symbol: TRXBTC, Price: 0.00000197', 'Symbol: TRXETH, Price: 0.00003564', 'Symbol: POWRBTC, Price: 0.00000344', 'Symbol: POWRETH, Price: 0.00006250', 'Symbol: ARKBTC, Price: 0.00001679', 'Symbol: ARKETH, Price: 0.00104600', 'Symbol: YOYOETH, Price: 0.00005828', 'Symbol: XRPBTC, Price: 0.00000755', 'Symbol: XRPETH, Price: 0.00013670', 'Symbol: MODBTC, Price: 0.00004280', 'Symbol: MODETH, Price: 0.00116700', 'Symbol: ENJBTC, Price: 0.00000312', 'Symbol: ENJETH, Price: 0.00005640', 'Symbol: STORJBTC, Price: 0.00000616', 'Symbol: STORJETH, Price: 0.00029910', 'Symbol: BNBUSDT, Price: 584.90000000', 'Symbol: VENBNB, Price: 0.14920000', 'Symbol: YOYOBNB, Price: 0.00059800', 'Symbol: POWRBNB, Price: 0.00385000', 'Symbol: VENBTC, Price: 0.00013928', 'Symbol: VENETH, Price: 0.00325194', 'Symbol: KMDBTC, Price: 0.00000513', 'Symbol: KMDETH, Price: 0.00020970', 'Symbol: NULSBNB, Price: 0.01257000', ...

# %%
print(okx_price())
# Out:
# ['Symbol: 1INCHEUR, Price: 0.3692', 'Symbol: MDTUSDT, Price: 0.05184', 'Symbol: LUNAUSDC, Price: 0.434', 'Symbol: OASUSDT, Price: 0.04821', 'Symbol: LINKBTC, Price: 0.000226', 'Symbol: KNCUSDT, Price: 0.5515', 'Symbol: IOTAUSDC, Price: 0.1709', 'Symbol: NEOBTC, Price: 0.000184', 'Symbol: DAIUSDT, Price: 1.0016', 'Symbol: LUNAUSDT, Price: 0.4342', 'Symbol: XNOUSDT, Price: 0.95', 'Symbol: ATOMETH, Price: 0.001931', 'Symbol: CVXUSDT, Price: 3.495', 'Symbol: AGLDUSDT, Price: 1.009', 'Symbol: JTOUSDT, Price: 2.429', 'Symbol: STETHETH, Price: 0.9997', 'Symbol: CRVBTC, Price: 0.00000447', 'Symbol: LSKUSDT, Price: 1.048', 'Symbol: IOTAUSDT, Price: 0.1717', 'Symbol: BONKUSDT, Price: 0.00002312', 'Symbol: AGLDUSDC, Price: 1.014', 'Symbol: JTOUSDC, Price: 2.341', 'Symbol: XRPUSDC, Price: 0.4776', 'Symbol: CROBTC, Price: 0.000001466', 'Symbol: APMUSDT, Price: 0.004351', 'Symbol: CHZEUR, Price: 0.07138', 'Symbol: QTUMUSDT, Price: 2.64', 'Symbol: CSPRUSDT, Price: 0.02202', 'Symbol: ELONUSDT, Price: 0.0000001591', 'Symbol: RUNECOINUSDT, Price: 0.00574', 'Symbol: SWEATUSDC, Price: 0.006207', 'Symbol: ZKJUSDT, Price: 1.1254', 'Symbol: CTXCUSDC, Price: 0.2224', 'Symbol: AVIVEUSDT, Price: 0.00608', 'Symbol: AXSUSDT, Price: 6.156', 'Symbol: XRPETH, Price: 0.0001365', 'Symbol: LQTYUSDT, Price: 0.898', 'Symbol: BCHUSDC, Price: 394.6', 'Symbol: KLAYUSDC, Price: 0.162', 'Symbol: VELOUSDT, Price: 0.010725', 'Symbol: ETCUSDT, Price: 23.88', 'Symbol: TAMAUSDT, Price: 0.002545', 'Symbol: ASTRUSDT, Price: 0.07137', 'Symbol: CTXCUSDT, Price: 0.2289', 'Symbol: BCHUSDT, Price: 395', 'Symbol: SAFEUSDT, Price: 1.445', 'Symbol: VELOUSDC, Price: 0.010679', 'Symbol: ETCUSDC, Price: 24', 'Symbol: XRPEUR, Price: 0.4447', 'Symbol: ASTRUSDC, Price: 0.07122', 'Symbol: ETHDAI, Price: 3503.63', 'Symbol: XRPTRY, Price: 15.71', 'Symbol: SANDUSDC, Price: 0.3356', 'Symbol: APTUSDT, Price: 7.205', 'Symbol: FRONTUSDT, Price: 0.8938', 'Symbol: GASUSDT, Price: 3.758', 'Symbol: TRXUSDT, Price: 0.1249', 'Symbol: CELRUSDT, Price: 0.01624', 'Symbol: CELOUSDT, Price: 0.6124', 'Symbol: WUSDT, Price: 0.3647', 'Symbol: CSPRUSDC, Price: 0.022', 'Symbol: LUNCEUR, Price: 0.00007619', 'Symbol: SANDUSDT, Price: 0.3355', 'Symbol: LATUSDT, Price: 0.00758', 'Symbol: APTUSDC, Price: 7.2', 'Symbol: LDOEUR, Price: 1.959', 'Symbol: DMAILUSDT, Price: 0.4285', 'Symbol: KLAYUSDT, Price: 0.1624', 'Symbol: TUSDT, Price: 0.0235', 'Symbol: SUNUSDT, Price: 0.011495', 'Symbol: CROUSDT, Price: 0.09295', 'Symbol: RAYUSDT, Price: 1.7947', 'Symbol: FLMUSDT, Price: 0.06882', 'Symbol: PEPEBRL, Price: 0.00006772', 'Symbol: CROEUR, Price: 0.08467', 'Symbol: XLMEUR, Price: 0.08376', 'Symbol: SOLUSDT, Price: 147.54', 'Symbol: API3USDT, Price: 2.241', 'Symbol: YFIUSDT, Price: 6352', 'Symbol: SWFTCUSDT, Price: 0.005373', 'Symbol: CROUSDC, Price: 0.09278', 'Symbol: ARBUSDC, Price: 0.8127', 'Symbol: LDOUSDT, Price: 2.065', 'Symbol: TRAUSDT, Price: 0.893', 'Symbol: MATICBTC, Price: 0.00000893', 'Symbol: MERLUSDT, Price: 0.3072', 'Symbol: FETUSDT, Price: 1.4278', 'Symbol: LINKEUR, Price: 13.355', 'Symbol: AAVEUSDC, Price: 98.5', 'Symbol: NMRUSDT, Price: 17.47', 'Symbol: UTKUSDT, Price: 0.0555', 'Symbol: TONUSDT, Price: 7.675', 'Symbol: DOGEUSDC, Price: 0.12664', 'Symbol: CORETRY, Price: 44.33', 'Symbol: AAVEUSDT, Price: 98.67', 'Symbol: LONUSDT, Price: 0.9496', 'Symbol: TONEUR, Price: 7.145', 'Symbol: TRBUSDT, Price: 97.3', 'Symbol: MATICUSDT, Price: 0.5663', 'Symbol: SWEATUSDT, Price: 0.006217', 'Symbol: DOGEUSDT, Price: 0.12674', 'Symbol: CETUSUSDC, Price: 0.07149', 'Symbol: SOLUSDC, Price: 147.38', 'Symbol: BICOUSDT, Price: 0.3896', 'Symbol: MATICUSDC, Price: 0.5652', 'Symbol: NEOUSDC, Price: 11.6', 'Symbol: FOXYUSDT, Price: 0.0180504', 'Symbol: XRPUSDT, Price: 0.4781', 'Symbol: ENSUSDT, Price: 32.759', 'Symbol: LPTUSDT, Price: 16.903', 'Symbol: BNBUSDT, Price: 585.1', 'Symbol: CHZBTC, Price: 0.000001206', 'Symbol: PRQUSDT, Price: 0.0879', 'Symbol: SPELLUSDT, Price: 0.0007257', 'Symbol: OMIUSDT, Price: 0.0005613', 'Sym ...
